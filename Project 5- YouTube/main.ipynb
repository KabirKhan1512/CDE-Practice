# %%
from googleapiclient.discovery import build
import time
import pandas as pd

# %%
# -------------------------------
# Configuration
# -------------------------------
api_key = "AIzaSyCTTKniDdoNeCVGlR2uXORZmF01ZjjJ6F4"
youtube = build("youtube", "v3", developerKey=api_key)

pakistani_channels = [
    "HAR PAL GEO",
    "ARY Digital HD",
    "HUM TV",
    "Moosa Tv Info",
    "Salman Noman",
    "Geo News",
    "Chota Ali vlogs",
    "Coke Studio Pakistan",
    "ARY News",
    "SAMAA TV",
    "Peep Peep",
    "Green TV Entertainment",
    "Anaya Eshaal Family",
    "G Factz",
    "AJ Official",
    "Nouman Hassan",
    "shaheer jutt",
    "Official Kashish PS",
    "malik abubaker",
    "UrduPoint.com",
    "Islamic Teacher Official",
    "Dunya News",
    "Tariq Jamil",
    "Top Pakistani Dramas",
    "BOL News",
    "Baby Viral Clips",
    "Shehr Main Dihat",
    "Rajab’s Family",
    "Lucky Sayed",
    "Break and Burn",
    "Kch Multimedia Naat",
    "Mehrban Ali",
    "Abdullah Tariq Khan",
    "Pyaar Lafzon Mein Kahan",
    "ISPR Official",
    "Hafiz Tahir Qadri",
    "92 News HD",
    "BOL Network",
    "S Plus",
    "Pakistan Cricket",
    "Imran Riaz Khan",
    "Chota_don047",
    "Zem TV",
    "Geo Kahani",
    "Sistrology",
    "Pakistan Super League",
    "Hasnain Technical",
    "Mister Explainer",
    "Rai Arslan Liaqat",
    "Dumb TV",
    "Three’s Threat",
    "Express News",
    "Food Fusion",
    "Haqeeqat TV",
    "BaBa Food RRC",
    "Express TV",
    "Maaz Safder World",
    "Minsa Saim Omer",
    "SGStudio",
    "Kitchen with Amna",
    "NomiAndFriends",
    "Village Food Secrets",
    "Amina Hussain",
    "mountainlion5",
    "HUM Sports",
    "Baba Che",
    "Naya Pakistan",
    "Sahir Ali Bagga",
    "MoonVines",
    "Rokhri Production Official",
    "Qasim Ali Shah Official",
    "Rohail Voice",
    "Daily Pakistan Global",
    "Atif Aslam",
    "GNN",
    "Unisys Music",
    "BaoRami Edits",
    "VAMPIRE YT",
    "Voice Daily",
    "Shahzaib Mughal",
    "Dilkash Beauty",
    "Madani Channel",
    "Chaudhary Saddam07",
    "Ahsan Bhai",
    "Its life",
    "Shero Ka Badshah",
    "Real Aryan khan",
    "Public News",
    "Allah Ki Qudrat",
    "Waqas khalil",
    "Ubqari",
    "SM Sadiq Studio",
    "So Cute",
    "ARY Qtv",
    "909Tv",
    "GFXMentor",
    "Capital TV",
    "Noaman Reaction",
    "Syed Fahad",
    "Info Industry"
]

# -------------------------------
# Function to fetch channel info
# -------------------------------
def get_channel_info(channel_name):
    try:
        request = youtube.search().list(
            part="snippet",
            q=channel_name,
            type="channel",
            maxResults=1
        )
        response = request.execute()
        if response["items"]:
            channel_id = response["items"][0]["snippet"]["channelId"]
            channel_title = response["items"][0]["snippet"]["title"]
            return {"name": channel_title, "id": channel_id}
        return {"name": channel_name, "id": None}
    except Exception as e:
        print(f"Error fetching {channel_name}: {e}")
        return {"name": channel_name, "id": None}

# -------------------------------
# Fetch IDs for all channels
# -------------------------------
channels_info = []
for name in pakistani_channels:
    info = get_channel_info(name)
    channels_info.append(info)
    print(info)
    time.sleep(0.1)  # slight delay to avoid hitting API rate limits

# -------------------------------
# channels_info now contains list of dicts
# -------------------------------
# Example output:
# [{'name': 'HAR PAL GEO', 'id': 'UCxxxxxx'}, {'name': 'ARY Digital HD', 'id': 'UCyyyyyy'}, ...]

# %%
channels_info

# %%
info
# Out:
# {'name': 'Info Industry', 'id': 'UCqXhcAQjPu0hOHslKvnUTtw'}

# %%
df = pd.DataFrame(channels_info)

# %%
df
# Out:
#                 name                        id
# 0        HAR PAL GEO  UCe9JSDmyqNgA_l2BzGHq1Ug
# 1     ARY Digital HD  UC4JCksJF76g_MdzPVBJoC3Q
# 2             HUM TV  UCEeEQxm6qc_qaTE7qTV5aLQ
# 3      Moosa Tv Info  UCsbCH2m8YUT11iqZv18b_PQ
# 4       Salman Noman  UCXTyWqKtLLzaom6XwaJu7xw
# ..               ...                       ...
# 95         GFXMentor  UCP3AIk974-PeB9bg1Mc7wug
# 96        Capital TV  UC-an6pHQfTVZXgrLP0p1EGA
# 97  Noaman Reaction   UCWAzKiL1zN9431hCmbDGkBw
# 98        Syed Fahad  UCAH_oGTGOA6fzEjIskPsMTA
# 99     Info Industry  UCqXhcAQjPu0hOHslKvnUTtw
#
# [100 rows x 2 columns]

# %%
df.to_csv("channel_name_id.csv")
